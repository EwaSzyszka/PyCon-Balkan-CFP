# %%
# %matplotlib notebook

import cv2
import matplotlib.pyplot as plt
import signal

# %%
def signal_handler(signal, frame):
    # KeyboardInterrupt detected, exiting
    global is_interrupted
    is_interrupted = True

# %%
vc = cv2.VideoCapture(0)

plt.ion()

if vc.isOpened(): # try to get the first frame
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
    webcam_preview = plt.imshow(frame)    
else:
    is_capturing = False

signal.signal(signal.SIGINT, signal_handler)
is_interrupted = False

while is_capturing:
    is_capturing, frame = vc.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    # makes the blues image look real colored
    webcam_preview.set_data(frame)
    plt.draw()
    #plt.savefig('books_read.png')

    try:    # Avoids a NotImplementedError caused by `plt.pause`
        plt.pause(0.05)
    except Exception:
        pass
    if is_interrupted:
        vc.release()
        break
        
        
#EDIT THIS CODE 
#1.) Import keyboard
#2.) If there is a key pressed on the keyboard take the screenshot of this video 
#3.) Then save this to file
#4.) Pass this file to the algorithm that you trained
# Out:
# <img src="data:image/png;base64,..." width="639.9">
# /Users/ewa_anna_szyszka/anaconda/lib/python2.7/site-packages/matplotlib/backend_bases.py:2453: MatplotlibDeprecationWarning: Using default event loop until function specific to this GUI is implemented
#   warnings.warn(str, mplDeprecation)
